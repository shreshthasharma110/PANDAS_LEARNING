# %% [markdown]
# <a href="https://colab.research.google.com/github/shreshthasharma110/PANDAS_LEARNING/blob/main/05_filtering_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df["median_income"]
# Out:
# 0        1.4936
# 1        1.8200
# 2        1.6509
# 3        3.1917
# 4        1.9250
#           ...
# 16995    2.3571
# 16996    2.5179
# 16997    3.0313
# 16998    1.9797
# 16999    3.0147
# Name: median_income, Length: 17000, dtype: float64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.iloc[10]
# Out:
# longitude              -114.6000
# latitude                 33.6200
# housing_median_age       16.0000
# total_rooms            3741.0000
# total_bedrooms          801.0000
# population             2434.0000
# households              824.0000
# median_income             2.6797
# median_house_value    86500.0000
# Name: 10, dtype: float64

# %% [markdown]
# filterning row

# %%
df[df['median_income']>5]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 32       -115.39     32.76                16.0       1136.0           196.0
# 69       -115.55     32.98                33.0       2266.0           365.0
# 92       -115.57     32.78                20.0       1534.0           235.0
# 98       -115.58     32.78                 5.0       2494.0           414.0
# 100      -115.59     32.79                 8.0       2183.0           307.0
# ...          ...       ...                 ...          ...             ...
# 16737    -122.89     38.38                16.0       2017.0           369.0
# 16762    -122.94     38.57                33.0       1530.0           266.0
# 16776    -123.00     38.33                 8.0       3223.0           637.0
# 16802    -123.17     39.18                14.0       2240.0           327.0
# 16899    -124.05     40.94                14.0       1452.0           217.0
#
# ...

# %% [markdown]
# multiple condition

# %%
df[(df["median_income"] > 5) & (df["housing_median_age"] > 20)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 69       -115.55     32.98                33.0       2266.0           365.0
# 260      -116.55     33.84                28.0       2992.0           562.0
# 352      -116.90     32.79                21.0       3770.0           491.0
# 363      -116.91     32.81                22.0       4331.0           637.0
# 364      -116.91     32.80                32.0       1943.0           287.0
# ...          ...       ...                 ...          ...             ...
# 16580    -122.70     38.46                29.0       2891.0           459.0
# 16620    -122.72     38.48                23.0       2296.0           356.0
# 16664    -122.76     38.35                30.0       2260.0           374.0
# 16735    -122.89     38.42                28.0       2388.0           437.0
# 16762    -122.94     38.57                33.0       1530.0           266.0
#
# ...

# %% [markdown]
# sorting values

# %%
df.sort_values("median_income")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6631     -118.28     33.93                52.0        117.0            33.0
# 11130    -121.01     37.65                52.0        178.0            53.0
# 10260    -119.99     36.09                23.0        333.0            92.0
# 15369    -122.29     37.81                46.0         12.0             4.0
# 2888     -117.75     34.06                52.0         62.0             9.0
# ...          ...       ...                 ...          ...             ...
# 7880     -118.40     34.10                27.0       3979.0           510.0
# 14883    -122.22     37.44                32.0       4281.0           501.0
# 15642    -122.36     37.56                32.0       4684.0           540.0
# 14884    -122.22     37.40                32.0       2297.0           287.0
# 4461     -118.04     34.13                35.0        249.0            31.0
#
# ...
