# %% [markdown]
# <a href="https://colab.research.google.com/github/shreshthasharma110/PANDAS_LEARNING/blob/main/01_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Creating a series in list

# %%
s = pd.Series([100,200,300,400,500,])
s
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([100, 200, 300, 400, 500])

# %%
s.index # to check index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# Assigning name to a column

# %%
s.name = 'calories'
s
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: calories, dtype: int64

# %% [markdown]
# Indexing

# %%
s[0]
# Out:
# np.int64(100)

# %%
s[0:3] # start(included) : stop(excluded) : step value(values to jump)
# Out:
# 0    100
# 1    200
# 2    300
# Name: Numbers, dtype: int64

# %%
s[0:5:2] # 2 is the step value
# Out:
# 0    100
# 2    300
# 4    500
# Name: Numbers, dtype: int64

# %%
# iloc -> location based indexing

s.iloc[3]
# Out:
# np.int64(400)

# %%
index = ["apple",'banana','grapes','oranges','pineapple']

# %%
s.index =index
s
# Out:
# apple        100
# banana       200
# grapes       300
# oranges      400
# pineapple    500
# Name: calories, dtype: int64

# %%
#loc -> label based indexing
s.loc['oranges']
# Out:
# np.int64(400)

# %%
# In label based indexing your start as well as stop value both are included in the output

# %% [markdown]
# Creating a series using dictionary

# %%
fruit_protien ={
    'Avocado': 2.0 ,  # protien in grams
    'Apple':5.0,
    'Blackberries':1.1,
    'Kiwi':7.0,
    'Mango':3.3,
    'Cherries':4.2
}

# %%
s2 = pd.Series(fruit_protien , name = 'protien in gm')
s2
# Out:
# Avocado         2.0
# Apple           5.0
# Blackberries    1.1
# Kiwi            7.0
# Mango           3.3
# Cherries        4.2
# Name: protien in gm, dtype: float64
