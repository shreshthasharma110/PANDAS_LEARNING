# %% [markdown]
# <a href="https://colab.research.google.com/github/shreshthasharma110/PANDAS_LEARNING/blob/main/03_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# creating a sample dataset[link text](https://)

# %%
employee_data = {
    "ID": [101, 102, 103, 104, 105],
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [24, 29, 31, 26, 28],
    "Department": ["HR", "IT", "Finance", "IT", "Marketing"],
    "Salary": [40000, 55000, 62000, 51000, 47000]
}

df = pd.DataFrame(employee_data)
df
# Out:
#     ID     Name  Age Department  Salary
# 0  101    Alice   24         HR   40000
# 1  102      Bob   29         IT   55000
# 2  103  Charlie   31    Finance   62000
# 3  104    David   26         IT   51000
# 4  105     Emma   28  Marketing   47000

# %%
df.to_csv('employee_data.csv' , index = False)

# %% [markdown]
# reading dataset

# %%
data = pd.read_csv('employee_data.csv')
data
# Out:
#     ID     Name  Age Department  Salary
# 0  101    Alice   24         HR   40000
# 1  102      Bob   29         IT   55000
# 2  103  Charlie   31    Finance   62000
# 3  104    David   26         IT   51000
# 4  105     Emma   28  Marketing   47000

# %%
data.head(3)
# Out:
#     ID     Name  Age Department  Salary
# 0  101    Alice   24         HR   40000
# 1  102      Bob   29         IT   55000
# 2  103  Charlie   31    Finance   62000

# %%
data.tail(3)
# Out:
#     ID     Name  Age Department  Salary
# 2  103  Charlie   31    Finance   62000
# 3  104    David   26         IT   51000
# 4  105     Emma   28  Marketing   47000

# %%
data.shape
# Out:
# (5, 5)

# %% [markdown]
# columns names

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
data['Salary']
# Out:
# 0    40000
# 1    55000
# 2    62000
# 3    51000
# 4    47000
# Name: Salary, dtype: int64

# %% [markdown]
# data types

# %%
data.dtypes
# Out:
# ID             int64
# Name          object
# Age            int64
# Department    object
# Salary         int64
# dtype: object

# %% [markdown]
# dataset information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          5 non-null      int64
#  1   Name        5 non-null      object
#  2   Age         5 non-null      int64
#  3   Department  5 non-null      object
#  4   Salary      5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 332.0+ bytes

# %% [markdown]
# Statistical Summary

# %%
data.describe()
# Out:
#                ID        Age        Salary
# count    5.000000   5.000000      5.000000
# mean   103.000000  27.600000  51000.000000
# std      1.581139   2.701851   8276.472679
# min    101.000000  24.000000  40000.000000
# 25%    102.000000  26.000000  47000.000000
# 50%    103.000000  28.000000  51000.000000
# 75%    104.000000  29.000000  55000.000000
# max    105.000000  31.000000  62000.000000

# %% [markdown]
# now inclduing text columns

# %%
data.describe(include = 'all')
# Out:
#                 ID   Name        Age Department        Salary
# count     5.000000      5   5.000000          5      5.000000
# unique         NaN      5        NaN          4           NaN
# top            NaN  Alice        NaN         IT           NaN
# freq           NaN      1        NaN          2           NaN
# mean    103.000000    NaN  27.600000        NaN  51000.000000
# std       1.581139    NaN   2.701851        NaN   8276.472679
# min     101.000000    NaN  24.000000        NaN  40000.000000
# 25%     102.000000    NaN  26.000000        NaN  47000.000000
# 50%     103.000000    NaN  28.000000        NaN  51000.000000
# 75%     104.000000    NaN  29.000000        NaN  55000.000000
# max     105.000000    NaN  31.000000        NaN  62000.000000
